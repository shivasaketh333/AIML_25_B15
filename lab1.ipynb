# %% [markdown]
# <a href="https://colab.research.google.com/github/shivasaketh333/AIML_25_B15/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
import numpy as np # Make sure numpy is imported

np.array([1, 2, 3]) # Use np.array instead of array
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
print(f" {array2} raised to the power of{array1}:,{array2**array1}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1:  [3.         1.         0.33333333]
# array2 raised to the power of array1:  [3 4 1]
#  [3 2 1] raised to the power of[1 2 3]:,[3 4 1]

# %%
people=['Ann',"Brandon",'Chen','David','Emily','Farook','Gagan','Hamish','Imran','Julio','Kartherine','Lily']
age=[21,12,32,45,37,18,28,52,5,40,48,15]
Weight=[55,35,77,68,70,60,72,69,18,65,82,48]
Height=[160,135,170,165,173,168,175,159,105,171,155,158]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Weight,Height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=15,fontstyle='italic')

#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8b6a4d084769> in <cell line: 5>()
#       3
#       4 #main plot function 'bar'
# ----> 5 plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
#       6
#       7 plt.xlabel("people",fontsize=15)
#
# NameError: name 'weight' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=15,fontstyle='italic')

#main plot function 'bar'
# Changed 'weight' to 'Weight' as it is the variable that stores the data
plt.bar(x=people,height=Weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt # Make sure to import matplotlib

plt.figure(figsize=(7,5))

# Assuming 'Weight' is the intended variable as it's defined in previous cells
# Replace 'weight' with 'Weight' if you have weight data stored in that variable
# If not, assign appropriate weight data to a variable named 'weight'
weight_data = [70, 75, 80, 65, 72, 85, 78, 73, 68, 76]  # Example weight data

#main plot function 'hist'
plt.hist(weight_data, color='red', edgecolor='k', alpha=0.75, bins=5)

plt.title("Histogram of patient weight", fontsize=18)
plt.xlabel("weight in kgs", fontsize=15)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.show()
